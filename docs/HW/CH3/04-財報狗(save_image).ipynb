# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve

url = "https://statementdog.com/"
response = requests.get(url)
response.encoding = "utf-8"
soup = BeautifulSoup(response.text, "html.parser")
all_imgs = soup.find_all("img")
# print(all_imgs)
for index, img in enumerate(all_imgs):
    try:
        image_path = img["src"]
        image_path = image_path.replace(" ", "")
        image_name = img["src"].split("/")[-1]
        print("image path is {} , file name is {}".format(image_path, image_name))
        urlretrieve(image_path, "save_image/" + image_name)
    except:
        continue
# Out:
# image path is https://www.facebook.com/tr?id=1265443774131605&ev=PageView&noscript=1 , file name is tr?id=1265443774131605&ev=PageView&noscript=1
# image path is https://cdn.statementdog.com/assets/statementdog-logo-e6a0879c1098381ced70afb78713ce646763442f4a2d91755c7cad23bc258611.png , file name is statementdog-logo-e6a0879c1098381ced70afb78713ce646763442f4a2d91755c7cad23bc258611.png
# image path is https://cdn.statementdog.com/assets/smart-logo-6c61e27d8d851c0822a6318cfe0dbfdc64a749d5b3e939447c1716e7a4a2df5f.svg , file name is smart-logo-6c61e27d8d851c0822a6318cfe0dbfdc64a749d5b3e939447c1716e7a4a2df5f.svg
# image path is https://cdn.statementdog.com/assets/businesstoday-logo-41fbfb74f1bf03dabc81616bad1a78b4e438e04789a1e123a58e2b5576f7e185.svg , file name is businesstoday-logo-41fbfb74f1bf03dabc81616bad1a78b4e438e04789a1e123a58e2b5576f7e185.svg
# image path is https://cdn.statementdog.com/assets/money-logo-9c5a6719a89306b357875540add19c272424460828ea347f4ef2721feff2ced8.svg , file name is money-logo-9c5a6719a89306b357875540add19c272424460828ea347f4ef2721feff2ced8.svg
# image path is https://cdn.statementdog.com/assets/bnext-logo-f577eea9b4956e7ca1fc0e2151beb534af47385b353d9b8099586df449ade3a9.svg , file name is bnext-logo-f577eea9b4956e7ca1fc0e2151beb534af47385b353d9b8099586df449ade3a9.svg
# image path is https://cdn.statementdog.com/assets/mirrormedia-logo-c1f192bbf6621a2562980d033305362e939a327861218820d68faeb459f72edd.svg , file name is mirrormedia-logo-c1f192bbf6621a2562980d033305362e939a327861218820d68faeb459f72edd.svg
# image path is https://cdn.statementdog.com/assets/ebc-logo-7750eca6859ed837977a547b60171dca7126c813584dfb6f708a8bd7cd8f2782.svg , file name is ebc-logo-7750eca6859ed837977a547b60171dca7126c813584dfb6f708a8bd7cd8f2782.svg
# image path is https://cdn.statementdog.com/assets/statementdog-logo-e6a0879c1098381ced70afb78713ce646763442f4a2d91755c7cad23bc258611.png , file name is statementdog-logo-e6a0879c1098381ced70afb78713ce646763442f4a2d91755c7cad23bc258611.png
