# %% [markdown]
# https://seaborn.pydata.org/introduction.html Seaborn 簡介

# %% [markdown]
# https://seaborn.pydata.org/tutorial/function_overview.html 功能關係圖

# %% [markdown]
# # **首先,關係圖 Relationship Plot relplot**

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")
print (tips.head())

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dots = sns.load_dataset("dots")
print (dots.head())
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
fmri = sns.load_dataset("fmri")
print (fmri.head())
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %% [markdown]
# # **線性回歸圖 Linear Regression Model lmplot**

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")

# %% [markdown]
# # **分布圖 Distribution Plot displot**

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)

# %% [markdown]
# # **用分布圖 kind = "ecdf"畫機率累計**

# %%
sns.displot(data=tips, kind="ecdf", x="total_bill", col="time", hue="smoker", rug=True)

# %% [markdown]
# # **類別圖 catplot 繪製類別型資料**

# %%
sns.catplot(data=tips, kind="swarm", x="day", y="total_bill", hue="smoker", height=6)

# %% [markdown]
# # **類別圖 Catplot, kind = 小提琴圖**

# %%
sns.catplot(data=tips, kind="violin", x="day", y="total_bill", hue="smoker", split=True, height=6)

# %% [markdown]
# # **類別圖 catplot Kind = BAR**

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker", height=6)

# %% [markdown]
# # **多變數資料集(multivariate dataset)的組合視角(composite view) jointplot**

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", height=7)

# %% [markdown]
# # **兩兩成對圖 pairplot**

# %%
sns.pairplot(data=penguins, hue="species")
