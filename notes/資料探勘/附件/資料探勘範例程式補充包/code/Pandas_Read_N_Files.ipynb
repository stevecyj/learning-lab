# %%
file_object = open ('sample1.csv', 'w+')
file_object.write('column1, column2\n')
file_object.write('1, 2\n')
file_object.close()

# %%
file_object = open ('sample2.csv', 'w+')
file_object.write('column1, column2\n')
file_object.write('3, 4\n')
file_object.close()

# %%
import os, fnmatch
#list = os.listdir('.')
csv_file_list = fnmatch.filter(os.listdir('.'), '*.csv')
for i in csv_file_list:
  print (i)
# Out:
# sample1.csv
# sample2.csv

# %%
import pandas as pd

list_of_dataframes = []
for filename in csv_file_list:
    list_of_dataframes.append(pd.read_csv(filename))

merged_df = pd.concat(list_of_dataframes)

print(merged_df)
# Out:
#    column1   column2
# 0        1         2
# 0        3         4
