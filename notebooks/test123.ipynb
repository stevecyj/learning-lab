# %%
name="Jisoo"
print(name)
# Out:
# Jisoo

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Volumes/data/Projects-practice/python-course/.venv/bin/python3
# 3.11.14 (main, Oct  9 2025, 16:16:55) [Clang 17.0.0 (clang-1700.0.13.3)]

# %%
print
